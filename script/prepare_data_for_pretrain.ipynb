# %%
import os
import pandas as pd
path = "/home/junsheng/data/ILSVR2012/train" # 也可采用 r" D:\Test_path" 或者是"D:/Test_path"
dir_list = []
# 方法一：使用 os.walk 方法遍历所有文件
for root,dirs,files in os.walk(path):
    for dir in dirs:
        dir_list.append(dir)

# %%
df = pd.DataFrame(columns=['class','filename'])
# df.loc[len(df.index)] = ['value1', 'value2']

# %%
df
# Out:
# Empty DataFrame
# Columns: [class, filename]
# Index: []

# %%
len(dir_list)
# Out:
# 1000

# %%
# i = 1
# for dir in dir_list[356:]:
#     temp_path = os.path.join(path,dir)
#     print(i,"/1000")
#     i += 1
#     for root,dirs,files in os.walk(temp_path):
#         # print("dirs",len(files))
#         for file_name in files:
#             df.loc[len(df.index)] = [dir, file_name]
# Out:
# 1 /1000
# 2 /1000
# 3 /1000
# 4 /1000
# 5 /1000
# 6 /1000
# 7 /1000
# 8 /1000
# 9 /1000
# 10 /1000
# 11 /1000
# 12 /1000
# 13 /1000
# 14 /1000
# 15 /1000
# 16 /1000
# 17 /1000
# 18 /1000
# 19 /1000
# 20 /1000
# 21 /1000
# 22 /1000
# 23 /1000
# 24 /1000
# 25 /1000
# 26 /1000
# 27 /1000
# 28 /1000
# 29 /1000
# 30 /1000
# 31 /1000
# 32 /1000
# 33 /1000
# 34 /1000
# 35 /1000
# 36 /1000
# 37 /1000
# 38 /1000
# 39 /1000
# 40 /1000
# 41 /1000
# 42 /1000
# 43 /1000
# 44 /1000
# 45 /1000
# 46 /1000
# 47 /1000
# 48 /1000
# 49 /1000
# 50 /1000
# 51 /1000
# 52 /1000
# 53 /1000
# 54 /1000
# 55 /1000
# 56 /1000
# 57 /1000
# 58 /1000
# 59 /1000
# 60 /1000
# 61 /1000
# 62 /1000
# 63 /1000
# 64 /1000
# 65 /1000
# 66 /1000
# 67 /1000
# 68 /1000
# 69 /1000
# 70 /1000
# 71 /1000
# 72 /1000
# 73 /1000
# 74 /1000
# 75 /1000
# 76 /1000
# 77 /1000
# 78 /1000
# 79 /1000
# 80 /1000
# 81 /1000
# 82 /1000
# 83 /1000
# 84 /1000
# 85 /1000
# 86 /1000
# 87 /1000
# 88 /1000
# 89 /1000
# 90 /1000
# 91 /1000
# ...

# %%
df.shape
df.head
# Out:
# <bound method NDFrame.head of              class              filename
# 0        n02119789   n02119789_3374.JPEG
# 1        n02119789  n02119789_13567.JPEG
# 2        n02119789   n02119789_6483.JPEG
# 3        n02119789   n02119789_7609.JPEG
# 4        n02119789   n02119789_4810.JPEG
# ...            ...                   ...
# 1283724  n03196217   n03196217_6163.JPEG
# 1283725  n03196217   n03196217_3423.JPEG
# 1283726  n03196217   n03196217_7634.JPEG
# 1283727  n03196217   n03196217_2128.JPEG
# 1283728  n03196217  n03196217_12552.JPEG
#
# [1283729 rows x 2 columns]>

# %%
df.to_csv("test_all.csv",index=False)

# %% [markdown]
# df.to_csv("test.csv",index=false)

# %% [markdown]
# df.to_csv("test.csv",index=false)
